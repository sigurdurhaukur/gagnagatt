# %%
# !pip install opencv-python
# !pip install mediapipe

# %%
import cv2
import time
import mediapipe as mp

# %%
def run_pose_estimation(video_path):
    mpDraw = mp.solutions.drawing_utils
    mpPose = mp.solutions.pose
    pose = mpPose.Pose()

    cap = cv2.VideoCapture(video_path)
    pTime = 0

    while cap.isOpened():
        ret, frame = cap.read()
        imgRGB = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(imgRGB)
        print(results.pose_landmarks)

        if results.pose_landmarks:
            mpDraw.draw_landmarks(frame, results.pose_landmarks, mpPose.POSE_CONNECTIONS)

        cTime = time.time()
        fps = 1 / (cTime - pTime)
        pTime = cTime

        cv2.putText(frame, f'FPS: {int(fps)}', (50, 50), cv2.FONT_HERSHEY_PLAIN, 2, (255, 0, 0), 1)
        

        frame = cv2.resize(frame, (int(2160/2), int(3840/2)))
        cv2.imshow('frame', frame)


        cv2.waitKey(1)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break


    cap.release()
    cv2.destroyAllWindows()


run_pose_estimation('./dancing.mp4')


# to handle multiple people in the frame
# you
# Out:
# landmark {
#   x: 0.518010675907135
#   y: 0.5227744579315186
#   z: -0.2532978653907776
#   visibility: 0.9999985694885254
# }
# landmark {
#   x: 0.5297501087188721
#   y: 0.5103479027748108
#   z: -0.22511795163154602
#   visibility: 0.9999983310699463
# }
# landmark {
#   x: 0.5368885397911072
#   y: 0.5097517371177673
#   z: -0.22521941363811493
#   visibility: 0.999997615814209
# }
# landmark {
#   x: 0.5439475178718567
#   y: 0.5094959735870361
#   z: -0.22543922066688538
#   visibility: 0.9999978542327881
# }
# landmark {
#   x: 0.5018380284309387
#   y: 0.5130061507225037
#   z: -0.2240518033504486
#   visibility: 0.9999984502792358
# }
# landmark {
#   x: 0.49240124225616455
#   y: 0.5138848423957825
#   z: -0.22396206855773926
#   visibility: 0.9999978542327881
# }
# landmark {
#   x: 0.48490282893180847
#   y: 0.5143903493881226
#   z: -0.22399736940860748
#   visibility: 0.9999983310699463
# }
# landmark {
#   x: 0.5578351616859436
#   y: 0.5163313150405884
# ...

# %%
mpDraw = mp.solutions.drawing_utils
mpPose = mp.solutions.pose

# Initialize pose estimation
pose = mpPose.Pose()

# Read the image
img = cv2.imread('./cycling-small.jpg')
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# flip the image
# imgRGB = cv2.flip(imgRGB, 1)
# img = cv2.flip(img, 1)


# Process the image
results = pose.process(imgRGB)
landmarks = results.pose_landmarks
# Draw pose landmarks on the image
if results.pose_landmarks:
    mpDraw.draw_landmarks(img, landmarks, mpPose.POSE_CONNECTIONS)

# Display the image
cv2.imshow('img', img)

# Wait for the user to press any key

cv2.waitKey(0)
cv2.destroyAllWindows()


# save the image
cv2.imwrite('./cycling-small-landmarks.jpg', img)
# Out:
# QObject::moveToThread: Current thread (0x5603d2adaf80) is not the object's thread (0x5603d31c4dd0).
# Cannot move to target thread (0x5603d2adaf80)
#
# QObject::moveToThread: Current thread (0x5603d2adaf80) is not the object's thread (0x5603d31c4dd0).
# Cannot move to target thread (0x5603d2adaf80)
#
# QObject::moveToThread: Current thread (0x5603d2adaf80) is not the object's thread (0x5603d31c4dd0).
# Cannot move to target thread (0x5603d2adaf80)
#
# QObject::moveToThread: Current thread (0x5603d2adaf80) is not the object's thread (0x5603d31c4dd0).
# Cannot move to target thread (0x5603d2adaf80)
#
# QObject::moveToThread: Current thread (0x5603d2adaf80) is not the object's thread (0x5603d31c4dd0).
# Cannot move to target thread (0x5603d2adaf80)
#
# QObject::moveToThread: Current thread (0x5603d2adaf80) is not the object's thread (0x5603d31c4dd0).
# Cannot move to target thread (0x5603d2adaf80)
#
# ...

# %%
# print(landmarks)
import numpy as np

img_height, img_width, _ = img.shape

# Get the coordinates of the left shoulder and hip
hip_l = landmarks.landmark[mpPose.PoseLandmark.LEFT_HIP]
shoulder_l = landmarks.landmark[mpPose.PoseLandmark.LEFT_SHOULDER]

# unnormalized pixel values


x1, y1= (shoulder_l.x * img_width, shoulder_l.y * img_height)
x2, y2 = (hip_l.x * img_width, hip_l.y * img_height)

# angle between the hips
angle_rad = np.arctan((y2 - y1) / (x2 - x1))


# Convert radians to degrees
angle_deg = np.degrees(angle_rad).astype(int) # sigfigs




print(angle_deg)
# Out:
# 59
